# %% [markdown]
# <a href="https://colab.research.google.com/github/Ehsan-Roohi/Cavity/blob/main/Relaxation_DSMC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ======================================================================
# FINAL ROBUST IMPLEMENTATION: Standard Supervised Deep Neural Network
# This version is optimized for GPU execution using a tf.data pipeline.
# ======================================================================

# --- Step 1: Imports and Setup ---
import numpy as np
import matplotlib.pyplot as plt
import numba
import time
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print("TensorFlow Version:", tf.__version__)
print("Numba Version:", numba.__version__)

# --- Step 2: DSMC Data Generation Function ---
# (Using the original, proven DSMC code)

# Constants
MOLAR_MASS_AR = 39.948e-3; AVOGADRO_NUM = 6.022e23; MASS_AR = MOLAR_MASS_AR / AVOGADRO_NUM; KB = 1.380649e-23; D_REF_AR = 4.17e-10; T_REF_AR = 273.0; OMEGA_VHS = 0.81

@numba.jit(nopython=True)
def calculate_vhs_cross_section_numba(vr_mag):
    if vr_mag < 1e-9: return 1e-30
    exponent = OMEGA_VHS - 0.5; c_ref_sq = 2 * KB * T_REF_AR / MASS_AR; gamma_val = 1.04533
    d_sq = (D_REF_AR**2) * ((c_ref_sq / vr_mag**2)**exponent) * (1 / gamma_val)
    return np.pi * d_sq

@numba.jit(nopython=True)
def perform_collisions_in_cell_numba(particles, indices_in_cell, cell_vol, dt, fnum, sigma_vr_max):
    num_particles_in_cell = len(indices_in_cell)
    if num_particles_in_cell < 2: return
    num_candidate_pairs = (num_particles_in_cell * (num_particles_in_cell - 1) * fnum * sigma_vr_max * dt) / (2.0 * cell_vol)
    num_pairs_to_select = int(np.floor(num_candidate_pairs + np.random.rand()))
    for _ in range(num_pairs_to_select):
        idx1_local = np.random.randint(0, num_particles_in_cell)
        idx2_local = np.random.randint(0, num_particles_in_cell)
        while idx1_local == idx2_local: idx2_local = np.random.randint(0, num_particles_in_cell)
        p1_idx, p2_idx = indices_in_cell[idx1_local], indices_in_cell[idx2_local]
        vrx, vry, vrz = particles[p1_idx, 1] - particles[p2_idx, 1], particles[p1_idx, 2] - particles[p2_idx, 2], particles[p1_idx, 3] - particles[p2_idx, 3]
        vr_mag = np.sqrt(vrx**2 + vry**2 + vrz**2)
        if vr_mag < 1e-9: continue
        sigma_t = calculate_vhs_cross_section_numba(vr_mag)
        if np.random.rand() < (sigma_t * vr_mag) / sigma_vr_max:
            vcm_x, vcm_y, vcm_z = 0.5 * (particles[p1_idx, 1] + particles[p2_idx, 1]), 0.5 * (particles[p1_idx, 2] + particles[p2_idx, 2]), 0.5 * (particles[p1_idx, 3] + particles[p2_idx, 3])
            cos_chi = 2 * np.random.rand() - 1.0; sin_chi = np.sqrt(1.0 - cos_chi**2); phi_chi = 2.0 * np.pi * np.random.rand()
            vr_prime_x, vr_prime_y, vr_prime_z = vr_mag * sin_chi * np.cos(phi_chi), vr_mag * sin_chi * np.sin(phi_chi), vr_mag * cos_chi
            particles[p1_idx, 1:4] = vcm_x + 0.5 * vr_prime_x, vcm_y + 0.5 * vr_prime_y, vcm_z + 0.5 * vr_prime_z
            particles[p2_idx, 1:4] = vcm_x - 0.5 * vr_prime_x, vcm_y - 0.5 * vr_prime_y, vcm_z - 0.5 * vr_prime_z

def run_dsmc_simulation(target_temp, params):
    print(f"\n--- Running DSMC for T = {target_temp} K with '{params['name']}' settings ---")
    NUM_CELLS_X = params['num_cells']; PARTICLES_PER_CELL_INIT = params['particles_per_cell']; TOTAL_TIME = params['total_time']; SAMPLING_START_TIME = params['sampling_start']
    TOTAL_PARTICLES_SIM = NUM_CELLS_X * PARTICLES_PER_CELL_INIT; LX=1.0e-6; RHO_INIT=1.78
    N_DENSITY_REAL = RHO_INIT / MASS_AR; CELL_VOLUME_CONCEPTUAL = (LX**3) / NUM_CELLS_X
    FNUM = (N_DENSITY_REAL * CELL_VOLUME_CONCEPTUAL) / PARTICLES_PER_CELL_INIT
    DT=1.0e-11; NUM_STEPS=int(TOTAL_TIME/DT); SAMPLING_START_STEP=int(SAMPLING_START_TIME/DT)
    particles = np.zeros((TOTAL_PARTICLES_SIM, 4)); cell_width = LX / NUM_CELLS_X
    for i in range(NUM_CELLS_X):
        start_idx, end_idx = i * PARTICLES_PER_CELL_INIT, (i + 1) * PARTICLES_PER_CELL_INIT
        particles[start_idx:end_idx, 0] = i * cell_width + np.random.rand(PARTICLES_PER_CELL_INIT) * cell_width
    particles[:, 1:4] = 800.0 * (2.0 * np.random.rand(TOTAL_PARTICLES_SIM, 3) - 1.0)
    current_total_ke = 0.5 * MASS_AR * np.sum(particles[:, 1:4]**2); target_total_ke = 1.5 * TOTAL_PARTICLES_SIM * KB * target_temp
    scaling_factor = np.sqrt(target_total_ke / current_total_ke); particles[:, 1:4] *= scaling_factor
    vr_max_estimate = 10.0 * np.sqrt(KB * target_temp / MASS_AR); SIGMA_VR_MAX_GLOBAL = calculate_vhs_cross_section_numba(vr_max_estimate) * vr_max_estimate
    sampled_speeds_accumulator = []
    print(f"Starting simulation for {NUM_STEPS} steps...")
    for step in range(1, NUM_STEPS + 1):
        particles[:, 0] = (particles[:, 0] + particles[:, 1] * DT) % LX
        cell_indices = (particles[:, 0] / cell_width).astype(np.int64); sorted_particle_indices = np.argsort(cell_indices)
        cell_counts = np.bincount(cell_indices, minlength=NUM_CELLS_X); cell_start_indices = np.concatenate(([0], np.cumsum(cell_counts[:-1])))
        for i in range(NUM_CELLS_X):
            start, end = cell_start_indices[i], cell_start_indices[i] + cell_counts[i]
            perform_collisions_in_cell_numba(particles, sorted_particle_indices[start:end], CELL_VOLUME_CONCEPTUAL, DT, FNUM, SIGMA_VR_MAX_GLOBAL)
        if step >= SAMPLING_START_STEP: sampled_speeds_accumulator.extend(np.sqrt(np.sum(particles[:, 1:4]**2, axis=1)))
        if step % (NUM_STEPS // 4) == 0: print(f"    ... T={target_temp}K, Step {step}/{NUM_STEPS} completed ...")
    print(f"DSMC for T = {target_temp} K finished. Collected {len(sampled_speeds_accumulator)} samples.")
    return np.array(sampled_speeds_accumulator)

# --- Step 3: High-Quality Data Generation and Preprocessing ---
simulation_params = {
    "name": "High Quality",
    "num_cells": 20,
    "particles_per_cell": 500,
    "total_time": 8.0e-7,
    "sampling_start": 4.0e-7,
}
training_temperatures = [200.0, 275.0, 350.0, 425.0, 500.0, 575.0, 650.0]
dsmc_results = {}
for temp in training_temperatures:
    dsmc_results[temp] = run_dsmc_simulation(target_temp=temp, params=simulation_params)

NUM_BINS = 200
X_train_list, y_train_list = [], []
for temp, speeds in dsmc_results.items():
    hist, bin_edges = np.histogram(speeds, bins=NUM_BINS, density=True)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2.0
    for i in range(len(bin_centers)):
        X_train_list.append([bin_centers[i], temp])
        y_train_list.append(hist[i])
print("\nInjecting physical boundary condition (v=0, P=0)...")
for temp in training_temperatures:
    X_train_list.append([0.0, temp])
    y_train_list.append(0.0)
X_train, y_train = np.array(X_train_list), np.array(y_train_list)
x_mean, x_std = np.mean(X_train, axis=0), np.std(X_train, axis=0)
X_train_normalized = (X_train - x_mean) / x_std
y_max = np.max(y_train)
y_train_normalized = y_train / y_max
print(f"\nCreated a high-quality training dataset with {len(X_train)} samples.")


# --- Step 4: Define and Train the Final, Stable DNN Model (GPU OPTIMIZED) ---

# --- GPU Optimization 1: Deeper Model Architecture ---
# A slightly deeper model can better leverage the parallel processing power of a GPU.
model = keras.Sequential([
    layers.Input(shape=(2,)),
    layers.Dense(512, activation='relu'),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'), # Added layer
    layers.Dense(1, activation='softplus')
], name="Final_DNN_GPU")
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')
model.summary()

# --- GPU Optimization 2: Use tf.data.Dataset for Efficient Data Input ---
# This creates a highly efficient data pipeline that feeds the GPU without bottlenecks.
BATCH_SIZE = 1024 # Larger batch sizes are often more efficient on GPUs
SHUFFLE_BUFFER = 10000

# Create training and validation datasets
from sklearn.model_selection import train_test_split
X_train_np, X_val_np, y_train_np, y_val_np = train_test_split(
    X_train_normalized, y_train_normalized, test_size=0.2, random_state=42
)

train_dataset = tf.data.Dataset.from_tensor_slices((X_train_np, y_train_np))
train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((X_val_np, y_val_np))
val_dataset = val_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

print(f"\nCreated tf.data pipelines with batch size {BATCH_SIZE}.")

print("\nStarting final model training (GPU Optimized)...")
history = model.fit(
    train_dataset, # Train on the efficient dataset
    epochs=500,
    validation_data=val_dataset, # Validate on the efficient dataset
    verbose=1,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
    ]
)
print("Training finished.")
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Final Model Training History'), plt.xlabel('Epoch'), plt.ylabel('Loss (MSE)')
plt.yscale('log'), plt.legend(), plt.grid(True), plt.show()


# --- Step 5: Evaluate the Final Model ---
def plot_final_prediction(test_temp):
    max_speed_in_data = np.max([np.max(s) for s in dsmc_results.values()])
    v_test = np.linspace(0, max_speed_in_data * 1.1, 300)
    nn_input = np.stack([v_test, np.full_like(v_test, test_temp)], axis=-1)
    nn_input_normalized = (nn_input - x_mean) / x_std
    predicted_pdf_normalized = model.predict(nn_input_normalized, verbose=0)
    predicted_pdf = predicted_pdf_normalized * y_max
    theoretical_pdf = (4*np.pi*(MASS_AR/(2*np.pi*KB*test_temp))**1.5 * v_test**2 * np.exp(-MASS_AR*v_test**2/(2*KB*test_temp)))
    plt.figure(figsize=(12, 8))
    plt.plot(v_test, theoretical_pdf, 'r-', linewidth=3, label=f'Theoretical Maxwell-Boltzmann (T={test_temp}K)')
    plt.plot(v_test, predicted_pdf, 'b--', linewidth=2.5, label=f'Final DNN Prediction (T={test_temp}K)')
    if test_temp in dsmc_results:
        plt.hist(dsmc_results[test_temp], bins=NUM_BINS, density=True, alpha=0.2, label=f'DSMC Data at {test_temp}K')
    plt.title(f'Final Model Prediction vs. Theoretical PDF', fontsize=16)
    plt.xlabel('Speed (m/s)'), plt.ylabel('Probability Density'), plt.legend(fontsize=12)
    plt.grid(True, linestyle=':'), plt.xlim(left=0), plt.ylim(bottom=0), plt.show()

print("\n--- Final Model Prediction for an UNSEEN temperature (325 K) ---")
plot_final_prediction(325.0)
print("\n--- Final Model Prediction for a SEEN temperature (500 K) ---")
plot_final_prediction(500.0)
# Out:
# TensorFlow Version: 2.18.0
# Numba Version: 0.60.0
#
# --- Running DSMC for T = 200.0 K with 'High Quality' settings ---
# Starting simulation for 80000 steps...
#     ... T=200.0K, Step 20000/80000 completed ...
#     ... T=200.0K, Step 40000/80000 completed ...
#     ... T=200.0K, Step 60000/80000 completed ...
#     ... T=200.0K, Step 80000/80000 completed ...
# DSMC for T = 200.0 K finished. Collected 400010000 samples.
#
# --- Running DSMC for T = 275.0 K with 'High Quality' settings ---
# Starting simulation for 80000 steps...
#     ... T=275.0K, Step 20000/80000 completed ...
#     ... T=275.0K, Step 40000/80000 completed ...
#     ... T=275.0K, Step 60000/80000 completed ...
#     ... T=275.0K, Step 80000/80000 completed ...
# DSMC for T = 275.0 K finished. Collected 400010000 samples.
#
# --- Running DSMC for T = 350.0 K with 'High Quality' settings ---
# Starting simulation for 80000 steps...
#     ... T=350.0K, Step 20000/80000 completed ...
#     ... T=350.0K, Step 40000/80000 completed ...
#     ... T=350.0K, Step 60000/80000 completed ...
#     ... T=350.0K, Step 80000/80000 completed ...
# DSMC for T = 350.0 K finished. Collected 400010000 samples.
#
# --- Running DSMC for T = 425.0 K with 'High Quality' settings ---
# Starting simulation for 80000 steps...
#     ... T=425.0K, Step 20000/80000 completed ...
#     ... T=425.0K, Step 40000/80000 completed ...
#     ... T=425.0K, Step 60000/80000 completed ...
#     ... T=425.0K, Step 80000/80000 completed ...
# DSMC for T = 425.0 K finished. Collected 400010000 samples.
#
# --- Running DSMC for T = 500.0 K with 'High Quality' settings ---
# Starting simulation for 80000 steps...
#     ... T=500.0K, Step 20000/80000 completed ...
#     ... T=500.0K, Step 40000/80000 completed ...
#     ... T=500.0K, Step 60000/80000 completed ...
#     ... T=500.0K, Step 80000/80000 completed ...
# DSMC for T = 500.0 K finished. Collected 400010000 samples.
#
# --- Running DSMC for T = 575.0 K with 'High Quality' settings ---
# Starting simulation for 80000 steps...
#     ... T=575.0K, Step 20000/80000 completed ...
#     ... T=575.0K, Step 40000/80000 completed ...
#     ... T=575.0K, Step 60000/80000 completed ...
#     ... T=575.0K, Step 80000/80000 completed ...
# DSMC for T = 575.0 K finished. Collected 400010000 samples.
#
# --- Running DSMC for T = 650.0 K with 'High Quality' settings ---
# Starting simulation for 80000 steps...
#     ... T=650.0K, Step 20000/80000 completed ...
#     ... T=650.0K, Step 40000/80000 completed ...
#     ... T=650.0K, Step 60000/80000 completed ...
#     ... T=650.0K, Step 80000/80000 completed ...
# DSMC for T = 650.0 K finished. Collected 400010000 samples.
#
# Injecting physical boundary condition (v=0, P=0)...
#
# Created a high-quality training dataset with 1407 samples.
# Model: "Final_DNN_GPU"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 512)            │         1,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 494,337 (1.89 MB)
#  Trainable params: 494,337 (1.89 MB)
#  Non-trainable params: 0 (0.00 B)
# Created tf.data pipelines with batch size 1024.
#
# Starting final model training (GPU Optimized)...
# Epoch 1/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 38s 20s/step - loss: 0.3044 - val_loss: 0.1492
# Epoch 2/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1563 - val_loss: 0.0840
# Epoch 3/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0774 - val_loss: 0.0868
# Epoch 4/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0726 - val_loss: 0.0866
# Epoch 5/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0704 - val_loss: 0.0751
# Epoch 6/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0601 - val_loss: 0.0564
# Epoch 7/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0454 - val_loss: 0.0406
# Epoch 8/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0355 - val_loss: 0.0349
# Epoch 9/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0333 - val_loss: 0.0322
# Epoch 10/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0320 - val_loss: 0.0284
# Epoch 11/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0276 - val_loss: 0.0265
# Epoch 12/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0243 - val_loss: 0.0270
# Epoch 13/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0240 - val_loss: 0.0258
# Epoch 14/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0232 - val_loss: 0.0230
# Epoch 15/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0213 - val_loss: 0.0207
# Epoch 16/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0197 - val_loss: 0.0191
# Epoch 17/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0185 - val_loss: 0.0180
# Epoch 18/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0179 - val_loss: 0.0170
# Epoch 19/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0169 - val_loss: 0.0160
# Epoch 20/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0161 - val_loss: 0.0151
# Epoch 21/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0152 - val_loss: 0.0147
# Epoch 22/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0142 - val_loss: 0.0140
# Epoch 23/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0135 - val_loss: 0.0124
# Epoch 24/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0122 - val_loss: 0.0111
# Epoch 25/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0113 - val_loss: 0.0106
# Epoch 26/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0106 - val_loss: 0.0101
# Epoch 27/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0095 - val_loss: 0.0084
# Epoch 28/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0085 - val_loss: 0.0076
# Epoch 29/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0079 - val_loss: 0.0077
# Epoch 30/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0066 - val_loss: 0.0084
# Epoch 31/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0064 - val_loss: 0.0062
# Epoch 32/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0048 - val_loss: 0.0039
# Epoch 33/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0048 - val_loss: 0.0032
# Epoch 34/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0033 - val_loss: 0.0068
# Epoch 35/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0044 - val_loss: 0.0027
# Epoch 36/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0022 - val_loss: 0.0031
# Epoch 37/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0041 - val_loss: 0.0016
# Epoch 38/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 39/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0023 - val_loss: 9.6121e-04
# Epoch 40/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014 - val_loss: 9.7520e-04
# Epoch 41/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 42/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0013 - val_loss: 6.5275e-04
# Epoch 43/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.1542e-04 - val_loss: 0.0012
# Epoch 44/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0011 - val_loss: 6.5663e-04
# Epoch 45/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2066e-04 - val_loss: 5.4977e-04
# Epoch 46/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.7086e-04 - val_loss: 8.0103e-04
# Epoch 47/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.6675e-04 - val_loss: 4.2548e-04
# Epoch 48/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.9981e-04 - val_loss: 4.8047e-04
# Epoch 49/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.7947e-04 - val_loss: 3.6792e-04
# Epoch 50/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.4218e-04 - val_loss: 3.5160e-04
# Epoch 51/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.2454e-04 - val_loss: 3.0478e-04
# Epoch 52/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.8947e-04 - val_loss: 2.7781e-04
# Epoch 53/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.6248e-04 - val_loss: 2.4763e-04
# Epoch 54/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.4902e-04 - val_loss: 2.2034e-04
# Epoch 55/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.2895e-04 - val_loss: 2.1850e-04
# Epoch 56/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.3082e-04 - val_loss: 1.8662e-04
# Epoch 57/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.0618e-04 - val_loss: 1.8022e-04
# Epoch 58/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.9958e-04 - val_loss: 1.5565e-04
# Epoch 59/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7206e-04 - val_loss: 1.6805e-04
# Epoch 60/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.8480e-04 - val_loss: 1.4662e-04
# Epoch 61/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.5520e-04 - val_loss: 1.3732e-04
# Epoch 62/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.4841e-04 - val_loss: 1.2573e-04
# Epoch 63/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4237e-04 - val_loss: 1.3058e-04
# Epoch 64/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.4453e-04 - val_loss: 1.0731e-04
# Epoch 65/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2713e-04 - val_loss: 1.0759e-04
# Epoch 66/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.2644e-04 - val_loss: 1.0400e-04
# Epoch 67/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.1925e-04 - val_loss: 1.0033e-04
# Epoch 68/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1571e-04 - val_loss: 1.0695e-04
# Epoch 69/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.1785e-04 - val_loss: 9.6175e-05
# Epoch 70/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.1258e-04 - val_loss: 8.3709e-05
# Epoch 71/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.0252e-04 - val_loss: 7.8404e-05
# Epoch 72/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.6279e-05 - val_loss: 7.4199e-05
# Epoch 73/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.6612e-05 - val_loss: 7.3816e-05
# Epoch 74/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.3054e-05 - val_loss: 6.5475e-05
# Epoch 75/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.7650e-05 - val_loss: 6.3673e-05
# Epoch 76/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.7841e-05 - val_loss: 7.8304e-05
# Epoch 77/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.6204e-05 - val_loss: 6.2768e-05
# Epoch 78/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.4433e-05 - val_loss: 7.1086e-05
# Epoch 79/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.4592e-05 - val_loss: 7.2712e-05
# Epoch 80/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.0429e-05 - val_loss: 6.4777e-05
# Epoch 81/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.0012e-05 - val_loss: 4.9157e-05
# Epoch 82/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.3969e-05 - val_loss: 7.3331e-05
# Epoch 83/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.0397e-05 - val_loss: 6.8785e-05
# Epoch 84/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.9280e-05 - val_loss: 4.6468e-05
# Epoch 85/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.9238e-05 - val_loss: 5.6345e-05
# Epoch 86/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.7673e-05 - val_loss: 6.0845e-05
# Epoch 87/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.2058e-05 - val_loss: 4.6624e-05
# Epoch 88/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.6548e-05 - val_loss: 6.0313e-05
# Epoch 89/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.5940e-05 - val_loss: 4.8019e-05
# Epoch 90/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.6696e-05 - val_loss: 6.0691e-05
# Epoch 91/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.6292e-05 - val_loss: 5.9122e-05
# Epoch 92/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.8898e-05 - val_loss: 4.5058e-05
# Epoch 93/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.3627e-05 - val_loss: 5.6337e-05
# Epoch 94/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.2693e-05 - val_loss: 4.7695e-05
# Epoch 95/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.4055e-05 - val_loss: 4.1197e-05
# Epoch 96/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.0653e-05 - val_loss: 3.5829e-05
# Epoch 97/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.4554e-05 - val_loss: 4.9269e-05
# Epoch 98/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.2968e-05 - val_loss: 4.9648e-05
# Epoch 99/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.7878e-05 - val_loss: 4.4864e-05
# Epoch 100/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.9683e-05 - val_loss: 4.0538e-05
# Epoch 101/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.0417e-05 - val_loss: 3.0276e-05
# Epoch 102/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.0638e-05 - val_loss: 3.0178e-05
# Epoch 103/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.0994e-05 - val_loss: 3.6561e-05
# Epoch 104/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.7887e-05 - val_loss: 3.9423e-05
# Epoch 105/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.6204e-05 - val_loss: 4.8704e-05
# Epoch 106/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.6359e-05 - val_loss: 2.8136e-05
# Epoch 107/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.5305e-05 - val_loss: 2.7955e-05
# Epoch 108/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.5256e-05 - val_loss: 2.7570e-05
# Epoch 109/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.4529e-05 - val_loss: 3.0064e-05
# Epoch 110/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.7111e-05 - val_loss: 2.6471e-05
# Epoch 111/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.3036e-05 - val_loss: 2.4413e-05
# Epoch 112/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.9680e-05 - val_loss: 2.5145e-05
# Epoch 113/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.0887e-05 - val_loss: 2.2852e-05
# Epoch 114/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.0283e-05 - val_loss: 2.2418e-05
# Epoch 115/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.8707e-05 - val_loss: 2.2893e-05
# Epoch 116/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7728e-05 - val_loss: 2.6826e-05
# Epoch 117/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.8774e-05 - val_loss: 2.3380e-05
# Epoch 118/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7061e-05 - val_loss: 2.5906e-05
# Epoch 119/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.9388e-05 - val_loss: 2.3910e-05
# Epoch 120/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.7175e-05 - val_loss: 2.1584e-05
# Epoch 121/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.7950e-05 - val_loss: 2.1805e-05
# Epoch 122/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.5419e-05 - val_loss: 1.8606e-05
# Epoch 123/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.2676e-05 - val_loss: 2.0043e-05
# Epoch 124/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.3739e-05 - val_loss: 3.2516e-05
# Epoch 125/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.3947e-05 - val_loss: 2.0179e-05
# Epoch 126/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.4342e-05 - val_loss: 1.8559e-05
# Epoch 127/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.1558e-05 - val_loss: 1.9327e-05
# Epoch 128/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.0602e-05 - val_loss: 2.1580e-05
# Epoch 129/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.5976e-05 - val_loss: 2.4829e-05
# Epoch 130/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.3841e-05 - val_loss: 2.0683e-05
# Epoch 131/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.5152e-05 - val_loss: 2.0664e-05
# Epoch 132/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.0809e-05 - val_loss: 1.7296e-05
# Epoch 133/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8844e-05 - val_loss: 2.1917e-05
# Epoch 134/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.1519e-05 - val_loss: 1.7005e-05
# Epoch 135/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8033e-05 - val_loss: 2.0725e-05
# Epoch 136/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1803e-05 - val_loss: 2.4232e-05
# Epoch 137/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1071e-05 - val_loss: 2.0997e-05
# Epoch 138/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.4109e-05 - val_loss: 2.0525e-05
# Epoch 139/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7768e-05 - val_loss: 2.9266e-05
# Epoch 140/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.9047e-05 - val_loss: 4.3633e-05
# Epoch 141/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.6605e-05 - val_loss: 5.3067e-05
# Epoch 142/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.0083e-05 - val_loss: 6.1214e-05
# Epoch 143/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.2114e-05 - val_loss: 3.7991e-05
# Epoch 144/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.2825e-05 - val_loss: 3.3170e-05
# Epoch 145/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.0615e-05 - val_loss: 3.3810e-05
# Epoch 146/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.9075e-05 - val_loss: 2.6631e-05
# Epoch 147/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.8300e-05 - val_loss: 2.5075e-05
# Epoch 148/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.1205e-05 - val_loss: 1.6775e-05
# Epoch 149/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6005e-05 - val_loss: 1.6775e-05
# Epoch 150/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5542e-05 - val_loss: 2.0998e-05
# Epoch 151/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.9333e-05 - val_loss: 2.4626e-05
# Epoch 152/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.4693e-05 - val_loss: 2.9055e-05
# Epoch 153/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.6356e-05 - val_loss: 2.0132e-05
# Epoch 154/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.9452e-05 - val_loss: 1.6283e-05
# Epoch 155/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3295e-05 - val_loss: 1.8188e-05
# Epoch 156/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6226e-05 - val_loss: 1.7859e-05
# Epoch 157/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4219e-05 - val_loss: 2.1941e-05
# Epoch 158/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6634e-05 - val_loss: 1.7566e-05
# Epoch 159/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4048e-05 - val_loss: 1.8992e-05
# Epoch 160/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.3908e-05 - val_loss: 1.3511e-05
# Epoch 161/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0328e-05 - val_loss: 1.4290e-05
# Epoch 162/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1624e-05 - val_loss: 1.8157e-05
# Epoch 163/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2632e-05 - val_loss: 2.1532e-05
# Epoch 164/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.8741e-05 - val_loss: 3.3168e-05
# Epoch 165/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.6934e-05 - val_loss: 2.5293e-05
# Epoch 166/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.0996e-05 - val_loss: 1.6214e-05
# Epoch 167/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0774e-05 - val_loss: 1.4315e-05
# Epoch 168/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1761e-05 - val_loss: 1.5859e-05
# Epoch 169/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0733e-05 - val_loss: 1.4211e-05
# Epoch 170/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9344e-05 - val_loss: 2.0105e-05
# Epoch 171/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3088e-05 - val_loss: 1.8708e-05
# Epoch 172/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2447e-05 - val_loss: 1.6021e-05
# Epoch 173/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1473e-05 - val_loss: 1.8375e-05
# Epoch 174/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1992e-05 - val_loss: 1.9893e-05
# Epoch 175/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4443e-05 - val_loss: 2.2068e-05
# Epoch 176/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4796e-05 - val_loss: 1.4105e-05
# Epoch 177/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.9155e-05 - val_loss: 1.0954e-05
# Epoch 178/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7479e-05 - val_loss: 2.0295e-05
# Epoch 179/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3234e-05 - val_loss: 1.7107e-05
# Epoch 180/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4334e-05 - val_loss: 1.2495e-05
# Epoch 181/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.6837e-05 - val_loss: 1.0356e-05
# Epoch 182/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6071e-05 - val_loss: 1.1456e-05
# Epoch 183/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6750e-05 - val_loss: 1.1513e-05
# Epoch 184/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5941e-05 - val_loss: 1.1567e-05
# Epoch 185/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5795e-05 - val_loss: 1.3519e-05
# Epoch 186/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9381e-05 - val_loss: 1.9246e-05
# Epoch 187/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2059e-05 - val_loss: 1.2984e-05
# Epoch 188/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9647e-05 - val_loss: 1.2490e-05
# Epoch 189/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6185e-05 - val_loss: 1.4897e-05
# Epoch 190/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7942e-05 - val_loss: 1.2304e-05
# Epoch 191/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6719e-05 - val_loss: 1.5493e-05
# Epoch 192/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.8168e-05 - val_loss: 1.0909e-05
# Epoch 193/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.5149e-05 - val_loss: 1.0071e-05
# Epoch 194/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.4115e-05 - val_loss: 9.3432e-06
# Epoch 195/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4366e-05 - val_loss: 9.3957e-06
# Epoch 196/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4203e-05 - val_loss: 9.5388e-06
# Epoch 197/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4166e-05 - val_loss: 1.1418e-05
# Epoch 198/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5052e-05 - val_loss: 1.1334e-05
# Epoch 199/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4201e-05 - val_loss: 1.2551e-05
# Epoch 200/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5817e-05 - val_loss: 1.1499e-05
# Epoch 201/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6371e-05 - val_loss: 1.6175e-05
# Epoch 202/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7547e-05 - val_loss: 1.5672e-05
# Epoch 203/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0322e-05 - val_loss: 2.1086e-05
# Epoch 204/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4544e-05 - val_loss: 3.0146e-05
# Epoch 205/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1681e-05 - val_loss: 3.4942e-05
# Epoch 206/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.5428e-05 - val_loss: 2.9989e-05
# Epoch 207/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.6524e-05 - val_loss: 2.2243e-05
# Epoch 208/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3252e-05 - val_loss: 2.2234e-05
# Epoch 209/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3311e-05 - val_loss: 6.7324e-05
# Epoch 210/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.1242e-05 - val_loss: 9.4005e-05
# Epoch 211/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.3431e-05 - val_loss: 8.4307e-05
# Epoch 212/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.4594e-05 - val_loss: 7.6540e-05
# Epoch 213/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.3443e-05 - val_loss: 8.3063e-05
# Epoch 214/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.5710e-05 - val_loss: 5.9027e-05
# Epoch 215/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.7806e-05 - val_loss: 5.2909e-05
# Epoch 216/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.1445e-05 - val_loss: 6.6043e-05
# Epoch 217/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.3831e-05 - val_loss: 3.7287e-05
# Epoch 218/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.5392e-05 - val_loss: 5.5188e-05
# Epoch 219/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.8812e-05 - val_loss: 6.9136e-05
# Epoch 220/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.6684e-05 - val_loss: 7.7754e-05
# Epoch 221/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.9802e-05 - val_loss: 5.4468e-05
# Epoch 222/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.9089e-05 - val_loss: 1.7049e-04
# Epoch 223/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5635e-04 - val_loss: 1.0479e-04
# Epoch 224/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.9371e-05 - val_loss: 7.8814e-05
# Epoch 225/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.2566e-05 - val_loss: 8.0103e-05
# Epoch 226/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.1257e-05 - val_loss: 9.2622e-05
# Epoch 227/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.1512e-05 - val_loss: 1.4006e-04
# Epoch 228/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.2315e-04 - val_loss: 1.5691e-04
# Epoch 229/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.3791e-04 - val_loss: 1.6907e-04
# Epoch 230/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.8144e-04 - val_loss: 1.5283e-04
# Epoch 231/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.2893e-04 - val_loss: 1.7046e-04
# Epoch 232/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6841e-04 - val_loss: 1.9481e-04
# Epoch 233/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6407e-04 - val_loss: 1.8415e-04
# Epoch 234/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5178e-04 - val_loss: 1.6647e-04
# Epoch 235/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4680e-04 - val_loss: 1.5353e-04
# Epoch 236/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2630e-04 - val_loss: 1.1617e-04
# Epoch 237/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0109e-04 - val_loss: 1.4889e-04
# Epoch 238/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.2388e-04 - val_loss: 1.1297e-04
# Epoch 239/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0441e-04 - val_loss: 7.2330e-05
# Epoch 240/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.6607e-05 - val_loss: 8.0273e-05
# Epoch 241/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.3544e-05 - val_loss: 1.2628e-04
# Epoch 242/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1580e-04 - val_loss: 1.0766e-04
# Epoch 243/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0517e-04 - val_loss: 9.3704e-05
# Epoch 244/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.0986e-05 - val_loss: 7.5672e-05
# Training finished.
# --- Final Model Prediction for an UNSEEN temperature (325 K) ---
# --- Final Model Prediction for a SEEN temperature (500 K) ---
